# %%
import thinkplot

# %%
import nsfg
df = nsfg.ReadFemPreg()
df
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN         6
# 1           1         2        NaN        NaN       NaN       NaN         6
# 2           2         1        NaN        NaN       NaN       NaN         5
# 3           2         2        NaN        NaN       NaN       NaN         6
# 4           2         3        NaN        NaN       NaN       NaN         6
# 5           6         1        NaN        NaN       NaN       NaN         6
# 6           6         2        NaN        NaN       NaN       NaN         6
# 7           6         3        NaN        NaN       NaN       NaN         6
# 8           7         1        NaN        NaN       NaN       NaN         5
# 9           7         2        NaN        NaN       NaN       NaN         5
# 10         12         1        NaN        NaN       NaN       NaN         5
# ...

# %%
df.ageqtnur.value_counts().sort_index()
# Out:
# 0      372
# 1      571
# 2      416
# 3      470
# 4      331
# 5      176
# 6      419
# 7      179
# 8      192
# 9      182
# 10     119
# 11      87
# 12     390
# 13      68
# 14      68
# 15      46
# 16      22
# 17      11
# 18      95
# 19       7
# 20      15
# 21       6
# 22      10
# 23       1
# 24      88
# 25       4
# 26       5
# 27       1
# 28       1
# 29       1
# 30      19
# 31       1
# 32       2
# 33       1
# 35       4
# 36      29
# 37       2
# 40       1
# 42       3
# 46       1
# 48       8
# 70       1
# 997      1
# dtype: int64

# %%
df.birthwgt_lb.value_counts().sort_index()
# Out:
# 0        8
# 1       40
# 2       53
# 3       98
# 4      229
# 5      697
# 6     2223
# 7     3049
# 8     1889
# 9      623
# 10     132
# 11      26
# 12      10
# 13       3
# 14       3
# 15       1
# dtype: int64

# %%
thinkplot.Scatter(xs=df.birthwgt_lb, ys=df.ageatend)
